# %% [markdown]
# # <center>**GRAPHIQUES BASIQUES POUR DECRIRE UNE VARIABLE**

# %% [markdown]
# <centre>_______________________________________________________________🛒— Supermarket Sales____________________________________________________________________________
#
# Le dataset Supermarket Sales contient des données sur les transactions effectuées dans un supermarché fictif. Il permet d’analyser les comportements d’achat des clients selon plusieurs dimensions : lieu, genre, méthode de paiement, type de produit, etc.

# %%
# Importation des librairies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
print(df.head())
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 📊 Description du graphique – Modes de paiement utilisés
# Le graphique présente la fréquence d’utilisation des différents modes de paiement par les clients du supermarché. Il s’agit d’un diagramme en barres verticales où chaque barre représente un mode de paiement.
# Les trois modes de paiement disponibles sont :
# 💳 Credit card /💵 Cash/📱 Ewallet
# Les hauteurs des barres indiquent le nombre de transactions effectuées avec chaque mode.
#
# Les barres sont généralement assez équilibrées, ce qui montre que les clients utilisent tous les moyens de paiement de manière assez homogène, avec de légères variations selon les préférences.
#
# Si la barre pour Ewallet est la plus haute, cela signifie que les portefeuilles électroniques sont le mode de paiement le plus utilisé dans ce supermarché.

# %%
sns.countplot(data=df, x="Payment")
plt.title("Modes de paiement utilisés")
plt.show()

# %% [markdown]
# 📦 Description du graphique – Total des ventes par genre
# Le graphique affiche un boxplot (ou boîte à moustaches) qui compare la distribution du montant total des ventes (Total) entre les deux genres : Male et Female.
#
# 🔹 Lecture du boxplot :
# Chaque boîte représente la distribution des montants dépensés par genre.
#
# La ligne au centre de chaque boîte indique la médiane (le montant au milieu de la distribution).
#
# Les bords de la boîte montrent le 1er et 3e quartile (50% des données).
#
# Les "moustaches" représentent l’étendue des données, et les points isolés sont les valeurs extrêmes (outliers).

# %%
sns.boxplot(data=df, x="Gender", y="Total")
plt.title("Total des ventes par genre")
plt.show()

# %% [markdown]
# 📦 Boxplot : Prix unitaire par ligne de produit
# Un boxplot (ou boîte à moustaches) permet de visualiser la distribution d'une variable (ici, Unit price) pour chaque groupe (ici, Product line).
#
# ✅ Ce que le graphique montre :
# La boîte représente les 50 % centraux des données (entre le 1er quartile Q1 et le 3e quartile Q3).
#
# La ligne à l’intérieur de la boîte est la médiane (Q2).
#
# Les moustaches montrent les valeurs minimum/maximum sans les outliers.
#
# Les points isolés sont des valeurs extrêmes (outliers).

# %%
sns.boxplot(x='Product line', y='Unit price', data=df)
plt.title("Prix unitaire par ligne de produit")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ___________________________________________________________________________________________________________________

# %% [markdown]
# # <font color=red> Histogramme

# %% [markdown]
# # <font color=PINK> PRICE UNITAIRE
# Analyse : Les prix unitaires sont répartis de manière assez uniforme entre 10 et 100.
#
# Interprétation : Il n'y a pas de concentration de prix spécifique, ce qui suggère une diversité de produits avec une large gamme de prix.

# %%
sns.histplot(df["Unit price"], kde=True, bins=30, color='lightblue')
plt.title("Histogramme des prix unitaires (Unit price)")
plt.xlabel("Prix unitaire")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# # 📈 Courbe de densité de la variable Quantity

# %% [markdown]
# Elle représente la distribution "lissée" du nombre de produits achetés par les clients.
#
# Contrairement à un histogramme en barres, la courbe de densité trace une courbe continue qui montre où les valeurs sont les plus fréquentes.
#
# Elle permet de voir plus facilement la forme globale de la distribution.

# %%
sns.kdeplot(df["Quantity"], fill=True)
plt.title("Densité de la quantité achetée")
plt.xlabel("Quantité")
plt.ylabel("Densité")
plt.show()

# %% [markdown]
# Ce code génère un histogramme d'une colonne d'un DataFrame (probablement appelé df) nommée "Tax 5%", avec une courbe d'Estimation de Densité par Noyau (KDE) superposée.

# %% [markdown]
# Si le pic de la courbe KDE est situé vers une valeur faible : cela pourrait indiquer que la majorité des taxes appliquées sont faibles, peut-être en raison d’une faible imposition ou d’un taux d'imposition réduit.
#
# Si l'histogramme est très large et légèrement étendu vers des valeurs plus élevées : cela pourrait signifier qu'il y a une certaine variation dans le montant des taxes, avec quelques valeurs beaucoup plus élevées que la moyenne.
#
# Si l'histogramme montre un pic avec peu de variation : cela indiquerait que la plupart des taxes sont concentrées autour d'une valeur spécifique, avec peu de fluctuations.

# %%
sns.histplot(df["Tax 5%"], kde=True, bins=30, color='salmon')
plt.title("Histogramme des taxes (5%)")
plt.xlabel("Montant de la taxe")
plt.ylabel("Fréquence")
plt.show()
